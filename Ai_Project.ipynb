# %%
import pandas as pd
import numpy as np 
import re
import pyarabic.araby as araby
import tweepy
import seaborn as sns
from textblob import TextBlob
from pyarabic.araby import strip_harakat
from pyarabic.araby import strip_tashkeel
from pyarabic.araby import strip_diacritics
from pyarabic.araby import strip_tatweel, strip_shadda
from pyarabic.araby import normalize_ligature
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression 
from sklearn.model_selection import cross_val_score 
from sklearn.metrics import f1_score
labels=['state','tweet']


df1=pd.read_csv('negative.tsv',sep='\t',names=labels)
df2=pd.read_csv("positive.tsv",sep="\t",names=labels)

# %%
df=df1.append(df2)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45275 entries, 0 to 22760
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   state   45275 non-null  object
#  1   tweet   45275 non-null  object
# dtypes: object(2)
# memory usage: 1.0+ MB

# %%
df.nunique()
# Out:
# state        2
# tweet    29449
# dtype: int64

# %%
df.shape
# Out:
# (45275, 2)

# %%
df
# Out:
#       state                                              tweet
# 0       neg  اعترف ان بتس كانو شوي شوي يجيبو راسي لكن اليوم...
# 1       neg  توقعت اذا جات داريا بشوفهم كاملين بس لي للحين ...
# 2       neg  #الاهلي_الهلال اكتب توقعك لنتيجة لقاء الهلال و...
# 3       neg  نعمة المضادات الحيوية . تضع قطرة💧مضاد بنسلين ع...
# 4       neg                             الدودو جايه تكمل علي 💔
# ...     ...                                                ...
# 22756   pos  السحب الليلة على الايفون .. رتويت للمرفقة وطبق...
# 22757   pos         😂 لابسة احمر ليه يا ست انتي ايه المناسبة 😂
# 22758   pos  كلاام جمييل تستاهل(من احبه الله جعل محبته ف قل...
# 22759   pos                   - ألطف صورة ممكن تعبر عن رمضان 💙
# 22760   pos  🌸 قال #الإمام_ابن_القيم -رحمه الله تعالى- : - ...
#
# [45275 rows x 2 columns]

# %%
 def remove_emojis(data) :
    emoj = re.compile("["
        u"\U0001F600-\U0001F64F"  # emoticons
        u"\U0001F300-\U0001F5FF"  # symbols & pictographs
        u"\U0001F680-\U0001F6FF"  # transport & map symbols
        u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
        u"\U00002500-\U00002BEF"  # chinese char
        u"\U00002702-\U000027B0"
        u"\U00002702-\U000027B0"
        u"\U000024C2-\U0001F251"
        u"\U0001f926-\U0001f937"
        u"\U00010000-\U0010ffff"
        u"\u2640-\u2642" 
        u"\u2600-\u2B55"
        u"\u200d"
        u"\u23cf"
        u"\u23e9"
        u"\u231a"
        u"\ufe0f"  # dingbats
        u"\u3030"
                      "]+", re.UNICODE)
    return re.sub(emoj, '', data)

# %%
 df['tweet']=df['tweet'].apply(remove_emojis)

# %%
df
# Out:
#       state                                              tweet
# 0       neg  اعترف ان بتس كانو شوي شوي يجيبو راسي لكن اليوم...
# 1       neg  توقعت اذا جات داريا بشوفهم كاملين بس لي للحين ...
# 2       neg  #الاهلي_الهلال اكتب توقعك لنتيجة لقاء الهلال و...
# 3       neg  نعمة المضادات الحيوية . تضع قطرةمضاد بنسلين عل...
# 4       neg                              الدودو جايه تكمل علي
# ...     ...                                                ...
# 22756   pos  السحب الليلة على الايفون .. رتويت للمرفقة وطبق...
# 22757   pos            لابسة احمر ليه يا ست انتي ايه المناسبة
# 22758   pos  كلاام جمييل تستاهل(من احبه الله جعل محبته ف قل...
# 22759   pos                    - ألطف صورة ممكن تعبر عن رمضان
# 22760   pos   قال #الإمام_ابن_القيم -رحمه الله تعالى- : - "...
#
# [45275 rows x 2 columns]

# %%
df['tweet']=df['tweet'].apply(strip_harakat)

# %%
df
# Out:
#       state                                              tweet
# 0       neg  اعترف ان بتس كانو شوي شوي يجيبو راسي لكن اليوم...
# 1       neg  توقعت اذا جات داريا بشوفهم كاملين بس لي للحين ...
# 2       neg  #الاهلي_الهلال اكتب توقعك لنتيجة لقاء الهلال و...
# 3       neg  نعمة المضادات الحيوية . تضع قطرةمضاد بنسلين عل...
# 4       neg                              الدودو جايه تكمل علي
# ...     ...                                                ...
# 22756   pos  السحب الليلة على الايفون .. رتويت للمرفقة وطبق...
# 22757   pos            لابسة احمر ليه يا ست انتي ايه المناسبة
# 22758   pos  كلاام جمييل تستاهل(من احبه الله جعل محبته ف قل...
# 22759   pos                    - ألطف صورة ممكن تعبر عن رمضان
# 22760   pos   قال #الإمام_ابن_القيم -رحمه الله تعالى- : - "...
#
# [45275 rows x 2 columns]

# %%
df['tweet']=df['tweet'].apply(strip_tashkeel)

# %%
df
# Out:
#       state                                              tweet
# 0       neg  اعترف ان بتس كانو شوي شوي يجيبو راسي لكن اليوم...
# 1       neg  توقعت اذا جات داريا بشوفهم كاملين بس لي للحين ...
# 2       neg  #الاهلي_الهلال اكتب توقعك لنتيجة لقاء الهلال و...
# 3       neg  نعمة المضادات الحيوية . تضع قطرةمضاد بنسلين عل...
# 4       neg                              الدودو جايه تكمل علي
# ...     ...                                                ...
# 22756   pos  السحب الليلة على الايفون .. رتويت للمرفقة وطبق...
# 22757   pos            لابسة احمر ليه يا ست انتي ايه المناسبة
# 22758   pos  كلاام جمييل تستاهل(من احبه الله جعل محبته ف قل...
# 22759   pos                    - ألطف صورة ممكن تعبر عن رمضان
# 22760   pos   قال #الإمام_ابن_القيم -رحمه الله تعالى- : - "...
#
# [45275 rows x 2 columns]

# %%
df['tweet']=df['tweet'].apply(araby.strip_diacritics)

# %%
df['tweet']=df['tweet'].apply(araby.strip_shadda)

# %%
df['tweet']=df['tweet'].apply(araby.strip_tatweel)

# %%
df['tweet']=df['tweet'].apply(araby.normalize_ligature)

# %%
df['tweet'] = df['tweet'].replace({'\#': '', ',': '','$':''}, regex=True)

# %%
df
# Out:
#       state                                              tweet
# 0       neg  اعترف ان بتس كانو شوي شوي يجيبو راسي لكن اليوم...
# 1       neg  توقعت اذا جات داريا بشوفهم كاملين بس لي للحين ...
# 2       neg  الاهلي_الهلال اكتب توقعك لنتيجة لقاء الهلال وا...
# 3       neg  نعمة المضادات الحيوية . تضع قطرةمضاد بنسلين عل...
# 4       neg                              الدودو جايه تكمل علي
# ...     ...                                                ...
# 22756   pos  السحب الليلة على الايفون .. رتويت للمرفقة وطبق...
# 22757   pos            لابسة احمر ليه يا ست انتي ايه المناسبة
# 22758   pos  كلاام جمييل تستاهل(من احبه الله جعل محبته ف قل...
# 22759   pos                    - ألطف صورة ممكن تعبر عن رمضان
# 22760   pos   قال الإمام_ابن_القيم -رحمه الله تعالى- : - " ...
#
# [45275 rows x 2 columns]

# %% [markdown]
# ### removing stop words

# %%
import nltk

# %%
from nltk.corpus import stopwords
arabic =stopwords.words('arabic')
print(len(arabic))
# Out:
# 754

# %%
nltk.download("stopwords")
# Out:
# [nltk_data] Error loading stopwords: <urlopen error [Errno 11001]
# [nltk_data]     getaddrinfo failed>
# False

# %%
#pip install arabicstopwords

# %%
from nltk.corpus import stopwords
arabic =stopwords.words('arabic')
print(len(arabic))
# Out:
# 754

# %%
print(arabic)
# Out:
# ['إذ', 'إذا', 'إذما', 'إذن', 'أف', 'أقل', 'أكثر', 'ألا', 'إلا', 'التي', 'الذي', 'الذين', 'اللاتي', 'اللائي', 'اللتان', 'اللتيا', 'اللتين', 'اللذان', 'اللذين', 'اللواتي', 'إلى', 'إليك', 'إليكم', 'إليكما', 'إليكن', 'أم', 'أما', 'أما', 'إما', 'أن', 'إن', 'إنا', 'أنا', 'أنت', 'أنتم', 'أنتما', 'أنتن', 'إنما', 'إنه', 'أنى', 'أنى', 'آه', 'آها', 'أو', 'أولاء', 'أولئك', 'أوه', 'آي', 'أي', 'أيها', 'إي', 'أين', 'أين', 'أينما', 'إيه', 'بخ', 'بس', 'بعد', 'بعض', 'بك', 'بكم', 'بكم', 'بكما', 'بكن', 'بل', 'بلى', 'بما', 'بماذا', 'بمن', 'بنا', 'به', 'بها', 'بهم', 'بهما', 'بهن', 'بي', 'بين', 'بيد', 'تلك', 'تلكم', 'تلكما', 'ته', 'تي', 'تين', 'تينك', 'ثم', 'ثمة', 'حاشا', 'حبذا', 'حتى', 'حيث', 'حيثما', 'حين', 'خلا', 'دون', 'ذا', 'ذات', 'ذاك', 'ذان', 'ذانك', 'ذلك', 'ذلكم', 'ذلكما', 'ذلكن', 'ذه', 'ذو', 'ذوا', 'ذواتا', 'ذواتي', 'ذي', 'ذين', 'ذينك', 'ريث', 'سوف', 'سوى', 'شتان', 'عدا', 'عسى', 'عل', 'على', 'عليك', 'عليه', 'عما', 'عن', 'عند', 'غير', 'فإذا', 'فإن', 'فلا', 'فمن', 'في', 'فيم', 'فيما', 'فيه', 'فيها', 'قد', 'كأن', 'كأنما', 'كأي', 'كأين', 'كذا', 'كذلك', 'كل', 'كلا', 'كلاهما', 'كلتا', 'كلما', 'كليكما', 'كليهما', 'كم', 'كم', 'كما', 'كي', 'كيت', 'كيف', 'كيفما', 'لا', 'لاسيما', 'لدى', 'لست', 'لستم', 'لستما', 'لستن', 'لسن', 'لسنا', 'لعل', 'لك', 'لكم', 'لكما', 'لكن', 'لكنما', 'لكي', 'لكيلا', 'لم', 'لما', 'لن', 'لنا', 'له', 'لها', 'لهم', 'لهما', 'لهن', 'لو', 'لولا', 'لوما', 'لي', 'لئن', 'ليت', 'ليس', 'ليسا', 'ليست', 'ليستا', 'ليسوا', 'ما', 'ماذا', 'متى', 'مذ', 'مع', 'مما', 'ممن', 'من', 'منه', 'منها', 'منذ', 'مه', 'مهما', 'نحن', 'نحو', 'نعم', 'ها', 'هاتان', 'هاته', 'هاتي', 'هاتين', 'هاك', 'هاهنا', 'هذا', 'هذان', 'هذه', 'هذي', 'هذين', 'هكذا', 'هل', 'هلا', 'هم', 'هما', 'هن', 'هنا', 'هناك', 'هنالك', 'هو', 'هؤلاء', 'هي', 'هيا', 'هيت', 'هيهات', 'والذي', 'والذين', 'وإذ', 'وإذا', 'وإن', 'ولا', 'ولكن', 'ولو', 'وما', 'ومن', 'وهو', 'يا', 'أبٌ', 'أخٌ', 'حمٌ', 'فو', 'أنتِ', 'يناير', 'فبراير', 'مارس', 'أبريل', 'مايو', 'يونيو', 'يوليو', 'أغسطس', 'سبتمبر', 'أكتوبر', 'نوفمبر', 'ديسمبر', 'جانفي', 'فيفري', 'مارس', 'أفريل', 'ماي', 'جوان', 'جويلية', 'أوت', 'كانون', 'شباط', 'آذار', 'نيسان', 'أيار', 'حزيران', 'تموز', 'آب', 'أيلول', 'تشرين', 'دولار', 'دينار', 'ريال', 'درهم', 'ليرة', 'جنيه', 'قرش', 'مليم', 'فلس', 'هللة', 'سنتيم', 'يورو', 'ين', 'يوان', 'شيكل', 'واحد', 'اثنان', 'ثلاثة', 'أربعة', 'خمسة', 'ستة', 'سبعة', 'ثمانية', 'تسعة', 'عشرة', 'أحد', 'اثنا', 'اثني', 'إحدى', 'ثلاث', 'أربع', 'خمس', 'ست', 'سبع', 'ثماني', 'تسع', 'عشر', 'ثمان', 'سبت', 'أحد', 'اثنين', 'ثلاثاء', 'أربعاء', 'خميس', 'جمعة', 'أول', 'ثان', 'ثاني', 'ثالث', 'رابع', 'خامس', 'سادس', 'سابع', 'ثامن', 'تاسع', 'عاشر', 'حادي', 'أ', 'ب', 'ت', 'ث', 'ج', 'ح', 'خ', 'د', 'ذ', 'ر', 'ز', 'س', 'ش', 'ص', 'ض', 'ط', 'ظ', 'ع', 'غ', 'ف', 'ق', 'ك', 'ل', 'م', 'ن', 'ه', 'و', 'ي', 'ء', 'ى', 'آ', 'ؤ', 'ئ', 'أ', 'ة', 'ألف', 'باء', 'تاء', 'ثاء', 'جيم', 'حاء', 'خاء', 'دال', 'ذال', 'راء', 'زاي', 'سين', 'شين', 'صاد', 'ضاد', 'طاء', 'ظاء', 'عين', 'غين', 'فاء', 'قاف', 'كاف', 'لام', 'ميم', 'نون', 'هاء', 'واو', 'ياء', 'همزة', 'ي', 'نا', 'ك', 'كن', 'ه', 'إياه', 'إياها', 'إياهما', 'إياهم', 'إياهن', 'إياك', 'إياكما', 'إياكم', 'إياك', 'إياكن', 'إياي', 'إيانا', 'أولالك', 'تانِ', 'تانِك', 'تِه', 'تِي', 'تَيْنِ', 'ثمّ', 'ثمّة', 'ذانِ', 'ذِه', 'ذِي', 'ذَيْنِ', 'هَؤلاء', 'هَاتانِ', 'هَاتِه', 'هَاتِي', 'هَاتَيْنِ', 'هَذا', 'هَذانِ', 'هَذِه', 'هَذِي', 'هَذَيْنِ', 'الألى', 'الألاء', 'أل', 'أنّى', 'أيّ', 'ّأيّان', 'أنّى', 'أيّ', 'ّأيّان', 'ذيت', 'كأيّ', 'كأيّن', 'بضع', 'فلان', 'وا', 'آمينَ', 'آهِ', 'آهٍ', 'آهاً', 'أُفٍّ', 'أُفٍّ', 'أفٍّ', 'أمامك', 'أمامكَ', 'أوّهْ', 'إلَيْكَ', 'إلَيْكَ', 'إليكَ', 'إليكنّ', 'إيهٍ', 'بخٍ', 'بسّ', 'بَسْ', 'بطآن', 'بَلْهَ', 'حاي', 'حَذارِ', 'حيَّ', 'حيَّ', 'دونك', 'رويدك', 'سرعان', 'شتانَ', 'شَتَّانَ', 'صهْ', 'صهٍ', 'طاق', 'طَق', 'عَدَسْ', 'كِخ', 'مكانَك', 'مكانَك', 'مكانَك', 'مكانكم', 'مكانكما', 'مكانكنّ', 'نَخْ', 'هاكَ', 'هَجْ', 'هلم', 'هيّا', 'هَيْهات', 'وا', 'واهاً', 'وراءَك', 'وُشْكَانَ', 'وَيْ', 'يفعلان', 'تفعلان', 'يفعلون', 'تفعلون', 'تفعلين', 'اتخذ', 'ألفى', 'تخذ', 'ترك', 'تعلَّم', 'جعل', 'حجا', 'حبيب', 'خال', 'حسب', ' ...

# %%
df['tweet_without_stopwords'] = df['tweet'].apply(lambda x: ' '.join([word for word in x.split() if word not in (arabic)]))

# %%
df.head(50)
# Out:
#    state                                              tweet  \
# 0    neg  اعترف ان بتس كانو شوي شوي يجيبو راسي لكن اليوم...
# 1    neg  توقعت اذا جات داريا بشوفهم كاملين بس لي للحين ...
# 2    neg  الاهلي_الهلال اكتب توقعك لنتيجة لقاء الهلال وا...
# 3    neg  نعمة المضادات الحيوية . تضع قطرةمضاد بنسلين عل...
# 4    neg                              الدودو جايه تكمل علي
# 5    neg  أحببته حتى أقنعنى إن ما فات من العمر كان إنتظا...
# 6    neg  يبدو ان دجلة اعتادت على التهام اجساد ابنائها م...
# 7    neg                                        جالس أذاكر
# 8    neg  يكفي استخفاف بالعقل العربي هل حقا الأمن والمخا...
# 9    neg                          ياليلل ترا اكلج كثير مشي
# 10   neg  لو بيدي أرجع ساعتي وين أرجع؟ إليا صدفه؟ والله ...
# 11   neg                              ليه محد يسوي معي كذا
# 12   neg  . . . . انت يمكن الي ناسي احداث البصرة قبل شهو...
# 13   neg                                      الله يعين بس
# 14   neg  اتفرج على اداءاتهم امس تقريبا كلهم قربوا من ال...
# 15   neg   تبي شي يقويك جنسيا   فوريفر تعطيك   *مجموعة ت...
# 16   neg                             مش وقته خالص التعب ده
# 17   neg  عرفنا انه الفلوس تغير النفوس أما تتغير وانت مف...
# 18   neg                             ربنا يرزقگ ببن الحلال
# 19   neg                           أجمل ما حل بي الوقوع بك
# 20   neg                                        مقبوله منك
# 21   neg                      السفير الامريكي كشف المستخبي
# 22   neg                                        الله يسلمك
# 23   neg  _ مناحل_ابو_سلطان . .  اقسم بالله انه عسل  . ....
# 24   neg  بنشكر الله انو القلب عضلة مو عظم .. بضل التعضي...
# 25   neg  و عندما تسألني عن أحباب هذا الزمان .. فأجيبك :...
# 26   neg                    ع الأقل الماي مايعور كثر النار
# 27   neg                                       واللي مستلم
# 28   neg  .لإ تغرگ ضحگتي ؤتقول مرتإح ;رگز بإلضحگهہ تسمع ...
# 29   neg    من يخاف فليس منا.. تصبحون على خير النصر_الاتحاد
# 30   neg  احد_الفيحاء مبروك للفيحاء الخروج من شبح الهبوط...
# 31   neg                                   لعب فينا البعوض
# 32   neg                  افتكرت فيه ناس يسونها طلعت وحيده
# 33   neg                                   لعب فينا البعوض
# 34   neg                                   سكتشاتي القديمه
# 35   neg                                    هذي المشكلهه :(
# 36   neg                      و للاسف انه يركض موب بس يمشي
# 37   neg                            كيف سويتي كذا ي اسطوره
# 38   neg  ~~ هناا_الوحي  تحذير للجماهيرالصفرااء سلامتك خ...
# 39   neg                      وانت ي حزين فرحتك هتكمل امتى
# 40   neg                          الابتسامه نفسها ما تتغير
# 41   neg                  ليه في ناس تكذب و تعطيك أمل زائف
# 42   neg  بنشكر الله انو القلب عضلة مو عظم .. بضل التعضي...
# 43   neg  عندما نشتاق لمن فقدناهم ، تغيب لذة كل شئ بالحي...
# 44   neg  . فهيدان_للدعم نجوم_الليل_للدعم  رغم كل شيء أس...
# 45   neg                                          بسم الله
# 46   neg                   نفس تفكيري خصوصا بوجود حمتو جنبه
# 47   neg  فعلا جيل أول مرتاحين نفسيا مو مثل اللحين كل وا...
# 48   neg    الواحد احيانا يتعب من جمال ابتسامة شخصه المفضل
# 49   neg                ي الله كيف الواحد يذاكر بذا الازعج
#
#                               tweet_without_stopwords
# 0   اعترف ان بتس كانو شوي شوي يجيبو راسي اليوم بال...
# 1   توقعت اذا جات داريا بشوفهم كاملين للحين احس اح...
# 2   الاهلي_الهلال اكتب توقعك لنتيجة لقاء الهلال وا...
# 3   نعمة المضادات الحيوية . تضع قطرةمضاد بنسلين بك...
# 4                                الدودو جايه تكمل علي
# 5                      أحببته أقنعنى فات العمر إنتظار
# 6   يبدو ان دجلة اعتادت التهام اجساد ابنائها سبايك...
# 7                                          جالس أذاكر
# 8   يكفي استخفاف بالعقل العربي الأمن والمخابرات أل...
# 9                            ياليلل ترا اكلج كثير مشي
# 10  بيدي أرجع ساعتي وين أرجع؟ إليا صدفه؟ والله أبق...
# 11                                   ليه محد يسوي معي
# 12  . . . . انت يمكن الي ناسي احداث البصرة شهور او...
# 13                                          الله يعين
# 14  اتفرج اداءاتهم امس تقريبا كلهم قربوا الفانز ال...
# 15  تبي شي يقويك جنسيا فوريفر تعطيك *مجموعة تعزيز ...
# 16                              مش وقته خالص التعب ده
# 17  عرفنا انه الفلوس تغير النفوس تتغير وانت مفلس ه...
# 18                              ربنا يرزقگ ببن الحلال
# 19                                     أجمل حل الوقوع
# 20                                         مقبوله منك
# 21                       السفير الامريكي كشف المستخبي
# 22                                         الله يسلمك
# 23  _ مناحل_ابو_سلطان . . اقسم بالله انه عسل . . ....
# 24  بنشكر الله انو القلب عضلة مو عظم .. بضل التعضي...
# 25  عندما تسألني أحباب الزمان .. فأجيبك : عابر ورا...
# 26                       الأقل الماي مايعور كثر النار
# 27                                        واللي مستلم
# 28  .لإ تغرگ ضحگتي ؤتقول مرتإح ;رگز بإلضحگهہ تسمع ...
# 29           يخاف فليس منا.. تصبحون خير النصر_الاتحاد
# 30  احد_الفيحاء مبروك للفيحاء الخروج شبح الهبوط بش...
# 31                                    لعب فينا البعوض
# 32                       افتكرت ناس يسونها طلعت وحيده
# 33                                    لعب فينا البعوض
# 34                                    سكتشاتي القديمه
# 35                                        المشكلهه :(
# 36                            للاسف انه يركض موب يمشي
# 37                                       سويتي اسطوره
# 38  ~~ هناا_الوحي تحذير للجماهيرالصفرااء سلامتك خي...
# 39                         وانت حزين فرحتك هتكمل امتى
# 40                              الابتسامه نفسها تتغير
# 41                        ليه ناس تكذب تعطيك أمل زائف
# 42  بنشكر الله انو القلب عضلة مو عظم .. بضل التعضي...
# 43  عندما نشتاق لمن فقدناهم ، تغيب لذة شئ بالحياة ...
# 44  . فهيدان_للدعم نجوم_الليل_للدعم رغم شيء أسمع د...
# 45                                           بسم الله
# 46                       تفكيري خصوصا بوجود حمتو جنبه
# 47              فعلا جيل مرتاحين نفسيا مو اللحين منفس
# 48        الواحد احيانا يتعب جمال ابتسامة شخصه المفضل
# 49                       الله الواحد يذاكر بذا الازعج

# %%
df.drop('tweet',axis=1,inplace=True)

# %%
df
# Out:
#       state                            tweet_without_stopwords
# 0       neg  اعترف ان بتس كانو شوي شوي يجيبو راسي اليوم بال...
# 1       neg  توقعت اذا جات داريا بشوفهم كاملين للحين احس اح...
# 2       neg  الاهلي_الهلال اكتب توقعك لنتيجة لقاء الهلال وا...
# 3       neg  نعمة المضادات الحيوية . تضع قطرةمضاد بنسلين بك...
# 4       neg                               الدودو جايه تكمل علي
# ...     ...                                                ...
# 22756   pos  السحب الليلة الايفون .. رتويت للمرفقة وطبق الشروط
# 22757   pos                   لابسة احمر ليه انتي ايه المناسبة
# 22758   pos  كلاام جمييل تستاهل(من احبه الله محبته قلوب البشر)
# 22759   pos                        - ألطف صورة ممكن تعبر رمضان
# 22760   pos  قال الإمام_ابن_القيم -رحمه الله تعالى- : - " ي...
#
# [45275 rows x 2 columns]

# %%
from sklearn.utils import shuffle
df = shuffle(df)

# %%
df
# Out:
#       state                            tweet_without_stopwords
# 9469    neg  إمسح قلبي الله انزعج وحين اغضب وحين أتألم وحين...
# 666     pos  الجميل التحرر مشاركة الزوجين أفكار بعضهما بلا ...
# 13176   neg                     الا مو مسويه تسجيل دخول بسفاري
# 10950   neg  انفجار غضب الشعبي Explosion of popular anger ف...
# 5131    neg           انا صبحت عليكم ومحد رد الا وحده وزعلت :(
# ...     ...                                                ...
# 21596   neg  أصفن أحاجي الروح وين عني سم بالكلب فركاك حط وك...
# 2041    neg  السهل تضع يدك فمك لآ. تتكلم آلصعب تضع يدك قلبك ك…
# 15640   pos  شكرا، يوم جمييل .. أكبر شكرا للدكتورة منى وفري...
# 13412   pos  فليشهد صباحي.. فى صدري لهفة واشتياق.. كبرياء ا...
# 20309   neg  القرقيعان قرب عادة حمد بن جاسم تنقطع لاكثر سنة...
#
# [45275 rows x 2 columns]

# %%
df.tweet_without_stopwords.isnull().sum()
# Out:
# 0

# %%
df.tweet_without_stopwords.value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 125                        ماهي هالليله وبس وانت متغير علي
# 14999                                     كلام جميل أستاذه
# 17494                                        ازاى كده لوول
# 7787                                          تنزل كريتف ؟
# 8882                                      والله اتفق مليون
#                                ...
# 14984                                         كفوو ابو سند
# 18096                   شوفو نضرات العابد والمعيوف جوفينكو
# 4075     ೋ ೋ اللهم أجعل دراستي أختباراتي كغيمة سريعة ، ...
# 5557     بالعكس دكتوره خيريه فنظرتك قمة الواقعيه وهي ال...
# 17660                                       انا صرت اضيعني
# Name: tweet_without_stopwords, Length: 45275, dtype: object>

# %%
df.tweet_without_stopwords.duplicated().sum()
# Out:
# 16410

# %%
df.duplicated().sum()
# Out:
# 16209

# %%
df.drop_duplicates().shape
# Out:
# (29066, 2)

# %%
df.tweet_without_stopwords.drop_duplicates()
# Out:
# 125                        ماهي هالليله وبس وانت متغير علي
# 14999                                     كلام جميل أستاذه
# 17494                                        ازاى كده لوول
# 7787                                          تنزل كريتف ؟
# 8882                                      والله اتفق مليون
#                                ...
# 13131      كنت كيوت والله وانا صغير شاركنا_صورتك_وانت_صغير
# 14984                                         كفوو ابو سند
# 18096                   شوفو نضرات العابد والمعيوف جوفينكو
# 5557     بالعكس دكتوره خيريه فنظرتك قمة الواقعيه وهي ال...
# 17660                                       انا صرت اضيعني
# Name: tweet_without_stopwords, Length: 28865, dtype: object

# %%
df.tweet_without_stopwords.drop_duplicates().shape
# Out:
# (28865,)

# %% [markdown]
# ### sentimnet analysis(to get )

# %%
df=df.copy()
def getSubjectivity(text):
     return TextBlob(text).sentiment.subjectivity
    
def getPolarity(text):
    return TextBlob(text).sentiment.polarity


df["sujectivity"]=df["tweet_without_stopwords"].apply(getSubjectivity)
df["polarity"]=df["tweet_without_stopwords"].apply(getPolarity)

# %%
df.head(50)
# Out:
#       state                            tweet_without_stopwords  sujectivity  \
# 9469    neg  إمسح قلبي الله انزعج وحين اغضب وحين أتألم وحين...     0.000000
# 666     pos  الجميل التحرر مشاركة الزوجين أفكار بعضهما بلا ...     0.000000
# 13176   neg                     الا مو مسويه تسجيل دخول بسفاري     0.000000
# 10950   neg  انفجار غضب الشعبي Explosion of popular anger ف...     0.616667
# 5131    neg           انا صبحت عليكم ومحد رد الا وحده وزعلت :(     1.000000
# 18705   neg  ٲليس العيب ان تحفظ الأغاني .. وتكرر السورة صلا...     0.000000
# 15568   neg  الحلقة التاسعة والعشرون السيرة النبوية تغريدات...     0.000000
# 13197   pos        قوتنا الله دائما الف مبرووك الحمد لله الشكر     0.000000
# 20490   pos  *إشراقة* *الاستغفار يمطر أرزاقا* *وأفراحا وسعا...     0.000000
# 3049    pos  " اجعل بينك وبين الله مشاريع خفية .. يعيد النا...     0.000000
# 14560   neg  هاذ رخوين فكرو السلام ضرب مبرح بسلم سلام عادي ...     0.000000
# 3587    neg  متضامن_مع_فائق_الشيخ_علي خاين العشرة ليش توكف ...     0.000000
# 2086    neg  . . . سبحانك اللهم وبحمدك، أشهد إله أستغفرك ال...     0.000000
# 22575   pos       الحمد لله مبروك يازعماء القادم أجمل شاء الله     0.000000
# 20090   neg  تجادلني حب الاهلي ، حتي لاتخسرني .. - اذهب وحب...     0.000000
# 14392   neg  احمد ربي ان تايمي ماهو مليان الاشكال تخيل معي ...     0.000000
# 18651   neg                        العشره ماتهون ال ابن الحرام     0.000000
# 22697   pos                                  مليون سعودي سنويا     0.000000
# 16038   neg           وهاذو علاه مخليينهم يغطو المسيرات مفهمتش     0.000000
# 17288   neg                 مارح شوفك لتعدي الأربع وعشرين ساعة     0.000000
# 13757   pos  احلى شي، لان احس ان صوت المنبه يقلب النفسيه يس...     0.000000
# 18977   pos                                   عليا الطلاق قلبي     0.000000
# 7665    pos                 صورة لتبديل الشفت الصباحي والمسائي     0.000000
# 12595   pos                                         وياك حبيبي     0.000000
# 22134   pos  بمناسبة فوز الهلال سحب مبلغ مالي شروط المسابقة...     0.000000
# 622     neg  النصر_الاتحاد توقع نتيجة مباراه النصر_الاتحاد ...     0.000000
# 10547   pos                       هاو اشدعوه ياحافظ ليش والخوف     0.000000
# 17751   pos  اللهم يوم الجمعه عافي مريض، وارحم امواتنا، اشر...     0.000000
# 10708   neg                وينك ياروز تعي شوفو هالمنحوس شو بدو     0.000000
# 16412   pos             جملة الرئيس السابق عمر البشير دي زابطه     0.000000
# 3428    pos  ربينا وكفينا أشعر أنه الحق أصرخ عليها أملي ابن...     0.000000
# 1490    neg  احيانا بتعدي عليا مواقف بقول يارب انا ال تفكير...     0.000000
# 1708    neg                               حسيتك اداعك فيا قاعد     0.000000
# 1876    pos  السعادة : يمر اسمك بدعاء أحدهم يوم علمك ربي سخ...     0.000000
# 11765   neg    والله اسمه مو زوران يصلح ثوران خلوني اكمل هدايا     0.000000
# 20950   pos  بمناسبة فوز الهلال .. سحب آيفون XR رتويت وتابع...     0.000000
# 17938   pos                                    زعولين .الطواقي     0.000000
# 2180    pos                                          ماخاب ظني     0.000000
# 16086   neg                    هه ادريي كلب والله ليه مزيون :(     1.000000
# 9583    pos  . إشراقة . قال يحيي بن أبي كثير : " يعجبك حلم ...     0.000000
# 1166    neg                                         سرع الايام     0.000000
# 6592    neg                                    حنان طلعت داشرة     0.000000
# 651     pos  أهم أسباب الفوز الهلال اليوم نجح التصدي لأكثر ...     0.000000
# 4020    neg                                   الله يهونها يارب     0.000000
# 4185    neg                                            اي باجر     0.000000
# 703     pos            الهلال المهمة الأولى "جدة" فيديو_الهلال     0.000000
# 21377   pos  جرذان المخلوع انقلابي النساء الحائرات طلقهم ال...     0.000000
# 12403   pos  بالله ، أحسن الظن بالله ، أحسن الله إليه صبحچ ...     0.000000
# 3467    neg  الاهلي_الهلال اكتب توقعك لنتيجة لقاء الهلال وا...     0.000000
# 1946    pos  اللهم ارزقني الموت توبة وعند الموت شهادة وبعد ...     0.000000
#
#        polarity
# 9469   0.000000
# 666    0.000000
# 13176  0.000000
# 10950  0.233333
# 5131  -0.750000
# 18705  0.000000
# 15568  0.000000
# 13197  0.000000
# 20490  0.000000
# 3049   0.000000
# 14560  0.000000
# 3587   0.000000
# 2086   0.000000
# 22575  0.000000
# 20090  0.000000
# 14392  0.000000
# 18651  0.000000
# 22697  0.000000
# 16038  0.000000
# 17288  0.000000
# 13757  0.000000
# 18977  0.000000
# 7665   0.000000
# 12595  0.000000
# 22134  0.000000
# 622    0.000000
# 10547  0.000000
# 17751  0.000000
# 10708  0.000000
# 16412  0.000000
# 3428   0.000000
# 1490   0.000000
# 1708   0.000000
# 1876   0.000000
# 11765  0.000000
# 20950  0.000000
# 17938  0.000000
# 2180   0.000000
# 16086 -0.750000
# 9583   0.000000
# 1166   0.000000
# 6592   0.000000
# 651    0.000000
# 4020   0.000000
# 4185   0.000000
# 703    0.000000
# 21377  0.000000
# 12403  0.000000
# 3467   0.000000
# 1946   0.000000

# %%
def getSentimentAnalysis(score):
    if score < 0 :
        return 'Negative'
    elif score == 0:
            return 'Neutral'
    else:
        return 'Positive'
    
df["Analysis"] = df["polarity"].apply(getSentimentAnalysis)

# %%
df.head(50)
# Out:
#       state                            tweet_without_stopwords  sujectivity  \
# 9469    neg  إمسح قلبي الله انزعج وحين اغضب وحين أتألم وحين...     0.000000
# 666     pos  الجميل التحرر مشاركة الزوجين أفكار بعضهما بلا ...     0.000000
# 13176   neg                     الا مو مسويه تسجيل دخول بسفاري     0.000000
# 10950   neg  انفجار غضب الشعبي Explosion of popular anger ف...     0.616667
# 5131    neg           انا صبحت عليكم ومحد رد الا وحده وزعلت :(     1.000000
# 18705   neg  ٲليس العيب ان تحفظ الأغاني .. وتكرر السورة صلا...     0.000000
# 15568   neg  الحلقة التاسعة والعشرون السيرة النبوية تغريدات...     0.000000
# 13197   pos        قوتنا الله دائما الف مبرووك الحمد لله الشكر     0.000000
# 20490   pos  *إشراقة* *الاستغفار يمطر أرزاقا* *وأفراحا وسعا...     0.000000
# 3049    pos  " اجعل بينك وبين الله مشاريع خفية .. يعيد النا...     0.000000
# 14560   neg  هاذ رخوين فكرو السلام ضرب مبرح بسلم سلام عادي ...     0.000000
# 3587    neg  متضامن_مع_فائق_الشيخ_علي خاين العشرة ليش توكف ...     0.000000
# 2086    neg  . . . سبحانك اللهم وبحمدك، أشهد إله أستغفرك ال...     0.000000
# 22575   pos       الحمد لله مبروك يازعماء القادم أجمل شاء الله     0.000000
# 20090   neg  تجادلني حب الاهلي ، حتي لاتخسرني .. - اذهب وحب...     0.000000
# 14392   neg  احمد ربي ان تايمي ماهو مليان الاشكال تخيل معي ...     0.000000
# 18651   neg                        العشره ماتهون ال ابن الحرام     0.000000
# 22697   pos                                  مليون سعودي سنويا     0.000000
# 16038   neg           وهاذو علاه مخليينهم يغطو المسيرات مفهمتش     0.000000
# 17288   neg                 مارح شوفك لتعدي الأربع وعشرين ساعة     0.000000
# 13757   pos  احلى شي، لان احس ان صوت المنبه يقلب النفسيه يس...     0.000000
# 18977   pos                                   عليا الطلاق قلبي     0.000000
# 7665    pos                 صورة لتبديل الشفت الصباحي والمسائي     0.000000
# 12595   pos                                         وياك حبيبي     0.000000
# 22134   pos  بمناسبة فوز الهلال سحب مبلغ مالي شروط المسابقة...     0.000000
# 622     neg  النصر_الاتحاد توقع نتيجة مباراه النصر_الاتحاد ...     0.000000
# 10547   pos                       هاو اشدعوه ياحافظ ليش والخوف     0.000000
# 17751   pos  اللهم يوم الجمعه عافي مريض، وارحم امواتنا، اشر...     0.000000
# 10708   neg                وينك ياروز تعي شوفو هالمنحوس شو بدو     0.000000
# 16412   pos             جملة الرئيس السابق عمر البشير دي زابطه     0.000000
# 3428    pos  ربينا وكفينا أشعر أنه الحق أصرخ عليها أملي ابن...     0.000000
# 1490    neg  احيانا بتعدي عليا مواقف بقول يارب انا ال تفكير...     0.000000
# 1708    neg                               حسيتك اداعك فيا قاعد     0.000000
# 1876    pos  السعادة : يمر اسمك بدعاء أحدهم يوم علمك ربي سخ...     0.000000
# 11765   neg    والله اسمه مو زوران يصلح ثوران خلوني اكمل هدايا     0.000000
# 20950   pos  بمناسبة فوز الهلال .. سحب آيفون XR رتويت وتابع...     0.000000
# 17938   pos                                    زعولين .الطواقي     0.000000
# 2180    pos                                          ماخاب ظني     0.000000
# 16086   neg                    هه ادريي كلب والله ليه مزيون :(     1.000000
# 9583    pos  . إشراقة . قال يحيي بن أبي كثير : " يعجبك حلم ...     0.000000
# 1166    neg                                         سرع الايام     0.000000
# 6592    neg                                    حنان طلعت داشرة     0.000000
# 651     pos  أهم أسباب الفوز الهلال اليوم نجح التصدي لأكثر ...     0.000000
# 4020    neg                                   الله يهونها يارب     0.000000
# 4185    neg                                            اي باجر     0.000000
# 703     pos            الهلال المهمة الأولى "جدة" فيديو_الهلال     0.000000
# 21377   pos  جرذان المخلوع انقلابي النساء الحائرات طلقهم ال...     0.000000
# 12403   pos  بالله ، أحسن الظن بالله ، أحسن الله إليه صبحچ ...     0.000000
# 3467    neg  الاهلي_الهلال اكتب توقعك لنتيجة لقاء الهلال وا...     0.000000
# 1946    pos  اللهم ارزقني الموت توبة وعند الموت شهادة وبعد ...     0.000000
#
#        polarity  Analysis
# 9469   0.000000   Neutral
# 666    0.000000   Neutral
# 13176  0.000000   Neutral
# 10950  0.233333  Positive
# 5131  -0.750000  Negative
# 18705  0.000000   Neutral
# 15568  0.000000   Neutral
# 13197  0.000000   Neutral
# 20490  0.000000   Neutral
# 3049   0.000000   Neutral
# 14560  0.000000   Neutral
# 3587   0.000000   Neutral
# 2086   0.000000   Neutral
# 22575  0.000000   Neutral
# 20090  0.000000   Neutral
# 14392  0.000000   Neutral
# 18651  0.000000   Neutral
# 22697  0.000000   Neutral
# 16038  0.000000   Neutral
# 17288  0.000000   Neutral
# 13757  0.000000   Neutral
# 18977  0.000000   Neutral
# 7665   0.000000   Neutral
# 12595  0.000000   Neutral
# 22134  0.000000   Neutral
# 622    0.000000   Neutral
# 10547  0.000000   Neutral
# 17751  0.000000   Neutral
# 10708  0.000000   Neutral
# 16412  0.000000   Neutral
# 3428   0.000000   Neutral
# 1490   0.000000   Neutral
# 1708   0.000000   Neutral
# 1876   0.000000   Neutral
# 11765  0.000000   Neutral
# 20950  0.000000   Neutral
# 17938  0.000000   Neutral
# 2180   0.000000   Neutral
# 16086 -0.750000  Negative
# 9583   0.000000   Neutral
# 1166   0.000000   Neutral
# 6592   0.000000   Neutral
# 651    0.000000   Neutral
# 4020   0.000000   Neutral
# 4185   0.000000   Neutral
# 703    0.000000   Neutral
# 21377  0.000000   Neutral
# 12403  0.000000   Neutral
# 3467   0.000000   Neutral
# 1946   0.000000   Neutral

# %%
sns.displot(df['Analysis'])

# %%
most_negative=df[df.polarity==-1].tweet_without_stopwords.head()
print(most_negative)
# Out:
# 10783             تعبت وانا اعيده يتعبب موت اف الموتشي :'(
# 3490     أرحمني الله بلغت التراقي وقيل راق والتفت الساق...
# 14098                  :( نفسي اطلع والله الجو كتير حلو !!
# 531      الى ؟ وانا احتري قلبك يلين :( والناس ! تتقدم و...
# 19316    اي مجال اطوف للدوام واطلع ؟ :( ياخي الجو بجنن!...
# Name: tweet_without_stopwords, dtype: object

# %%
most_positive=df[df.polarity==1].tweet_without_stopwords.tail()
print(most_positive)
# Out:
# 20873                             بقت نواقض الرجولة ايه :D
# 11858            :D فرتكتى الجبهة بتاعتنا ده شكله عبيط فكك
# 2909     يقولون ان الدنيا حلوه :D — watching Karmouz Wa...
# 16718                 يعني هحس بالرضا الموبايل يتكسر :D :D
# 6001     مين احلى انا احلى شوية طبعا بنات روسيا جامدين ...
# Name: tweet_without_stopwords, dtype: object

# %%
# Convert Textual data to feature vectors
x=df['tweet_without_stopwords'].values

# %%
vectorizer = TfidfVectorizer(max_features=100,
                              max_df=0.8,
                              min_df=5,
                             ngram_range=(1,3))

vectors=vectorizer.fit_transform(x)

# %%
print(vectors)
# Out:
#   (0, 50)	0.6686951489651854
#   (0, 24)	0.3717912482134661
#   (0, 79)	0.6439084294387682
#   (1, 43)	1.0
#   (2, 87)	0.689222717483951
#   (2, 11)	0.7245495467558019
#   (4, 73)	0.6349267401013742
#   (4, 39)	0.4867576423851652
#   (4, 11)	0.5999458577937493
#   (5, 38)	1.0
#   (7, 15)	0.4307714981284334
#   (7, 82)	0.3926648254325299
#   (7, 14)	0.4154593599161008
#   (7, 22)	0.4552463364247816
#   (7, 53)	0.4676007557803295
#   (7, 24)	0.2484835565823403
#   (9, 29)	0.8478603212372252
#   (9, 24)	0.5302196485151311
#   (11, 87)	1.0
#   (12, 25)	1.0
#   (13, 67)	0.3808985848805159
#   (13, 66)	0.37933878862829357
#   (13, 8)	0.3966530080448548
#   (13, 84)	0.38700657609925226
#   (13, 15)	0.36132309780196814
#   :	:
#   (45260, 44)	1.0
#   (45262, 77)	0.6853530152681875
#   (45262, 23)	0.6373870238968075
#   (45262, 24)	0.3521775492997446
#   (45263, 24)	1.0
#   (45264, 76)	0.32030261863549603
#   (45264, 49)	0.3139406641290854
#   (45264, 32)	0.32030261863549603
#   (45264, 75)	0.31178297611888967
#   (45264, 48)	0.3139406641290854
#   (45264, 19)	0.28691237226789557
#   (45264, 57)	0.2787510089831691
#   (45264, 63)	0.2956849341592801
#   (45264, 31)	0.2530698090774224
#   (45264, 74)	0.30226337931828
#   (45264, 47)	0.3124555427634787
#   (45266, 70)	0.6083243151256416
#   (45266, 30)	0.5444698500561876
#   (45266, 50)	0.5774894890876472
#   (45269, 26)	0.6413049816177642
#   (45269, 98)	0.7672860747806123
#   (45272, 99)	1.0
#   (45273, 13)	0.7390035838846579
#   (45273, 40)	0.673701493990945
#   (45274, 41)	1.0

# %%
feature_names = vectorizer.get_feature_names()

# %%
print(feature_names)
# Out:
# ['neg', 'pos', 'xr', 'xr رتويت', 'xr رتويت وتابع', 'آيفون', 'آيفون xr', 'آيفون xr رتويت', 'أجمل', 'اذا', 'ال', 'الا', 'الاتحاد', 'الحب', 'الحمد', 'الحمد لله', 'الحياة', 'الخير', 'الدنيا', 'السحب', 'السحب ساعة', 'السحب ساعة موثق', 'الف', 'القلب', 'الله', 'اللهم', 'اللي', 'الليلة', 'المطر', 'الناس', 'النصر', 'الهلال', 'الهلال سحب', 'الهلال سحب آيفون', 'الهلال_الاهلي', 'الى', 'الي', 'اليوم', 'ان', 'انا', 'انت', 'انه', 'اني', 'او', 'اي', 'بالفديو', 'بالله', 'بمناسبة', 'بمناسبة فوز', 'بمناسبة فوز الهلال', 'ترى', 'جدا', 'خير', 'دائما', 'دي', 'رب', 'ربي', 'رتويت', 'رتويت وتابع', 'رتويت وتابع السحب', 'ساعة', 'ساعة موثق', 'ساعة موثق بالفديو', 'سحب', 'سحب آيفون', 'سحب آيفون xr', 'شاء', 'شاء الله', 'شي', 'شيء', 'ضد', 'عشان', 'علي', 'عليكم', 'فوز', 'فوز الهلال', 'فوز الهلال سحب', 'فيك', 'قال', 'قلبي', 'كانت', 'كنت', 'لله', 'مافي', 'مبروك', 'محمد', 'مش', 'مو', 'موثق', 'موثق بالفديو', 'هه', 'والله', 'وانا', 'وتابع', 'وتابع السحب', 'وتابع السحب ساعة', 'وش', 'يارب', 'يعني', 'يوم']

# %% [markdown]
# ### cross validation using (k-fold)

# %%
from sklearn.model_selection import KFold
kf= KFold(n_splits=20 ,random_state = 22 , shuffle = True )
i = 1
for train_index,test_index in kf.split(df):
    print("Fold",i)
    print ("train data: ", train_index, "\n")
    print (" test data :",test_index)
    i +=1
# Out:
# Fold 1
# train data:  [    0     1     2 ... 45272 45273 45274]
#
#  test data : [   20    27    72 ... 45205 45232 45256]
# Fold 2
# train data:  [    0     1     2 ... 45272 45273 45274]
#
#  test data : [    4     8    13 ... 45171 45186 45192]
# Fold 3
# train data:  [    0     1     2 ... 45271 45273 45274]
#
#  test data : [   30    32    50 ... 45255 45264 45272]
# Fold 4
# train data:  [    0     1     2 ... 45272 45273 45274]
#
#  test data : [   53    55    56 ... 45218 45240 45254]
# Fold 5
# train data:  [    0     1     2 ... 45272 45273 45274]
#
#  test data : [   48    60    62 ... 45260 45266 45268]
# Fold 6
# train data:  [    0     1     2 ... 45272 45273 45274]
#
#  test data : [    7    16    24 ... 45179 45223 45246]
# Fold 7
# train data:  [    0     1     4 ... 45272 45273 45274]
#
#  test data : [    2     3    81 ... 45208 45233 45250]
# Fold 8
# train data:  [    0     1     2 ... 45272 45273 45274]
#
#  test data : [   14    31    36 ... 45220 45230 45245]
# Fold 9
# train data:  [    0     2     3 ... 45272 45273 45274]
#
#  test data : [    1    11    25 ... 45100 45170 45174]
# Fold 10
# train data:  [    0     1     2 ... 45272 45273 45274]
#
#  test data : [   38    39    43 ... 45169 45195 45248]
# Fold 11
# train data:  [    0     1     2 ... 45272 45273 45274]
#
#  test data : [    9    65    71 ... 45258 45263 45270]
# Fold 12
# train data:  [    1     2     3 ... 45272 45273 45274]
#
#  test data : [    0    19    63 ... 45257 45262 45267]
# Fold 13
# train data:  [    0     1     2 ... 45272 45273 45274]
#
#  test data : [   18    26    64 ... 45221 45226 45238]
# Fold 14
# train data:  [    0     1     2 ... 45271 45272 45274]
#
#  test data : [   10    44    93 ... 45259 45265 45273]
# Fold 15
# train data:  [    0     1     2 ... 45272 45273 45274]
#
#  test data : [   17    45    75 ... 45222 45225 45261]
# Fold 16
# train data:  [    0     1     2 ... 45270 45272 45273]
#
#  test data : [   12    42    47 ... 45198 45271 45274]
# Fold 17
# train data:  [    0     1     2 ... 45272 45273 45274]
#
#  test data : [    5    34    54 ... 45237 45241 45251]
# Fold 18
# train data:  [    0     1     2 ... 45272 45273 45274]
#
#  test data : [   22    29    37 ... 45207 45227 45242]
# Fold 19
# train data:  [    0     1     2 ... 45272 45273 45274]
#
#  test data : [   15    73    95 ... 45239 45243 45269]
# Fold 20
# train data:  [    0     1     2 ... 45272 45273 45274]
#
#  test data : [    6    21    35 ... 45228 45249 45252]

# %%
Y=df['state']
classifier1 = LogisticRegression()
accuracy=cross_val_score(classifier1  ,vectors,Y , cv=kf, scoring='accuracy'  , n_jobs= -1 ).mean()
print("accuracy=",accuracy)
classifier1.fit(vectors,Y)
y_pred= classifier1.predict(vectors)
F_score=f1_score(Y,y_pred,average='macro')
print("F1_score=",F_score)
# Out:
# accuracy= 0.6168518192492846
# F1_score= 0.604438847361702

# %%
from sklearn.svm import SVC
Y=df['state']
svm=SVC()
accuracy=cross_val_score(svm ,vectors,Y , cv=kf, scoring='accuracy'  , n_jobs= -1 ).mean()
print("accuracy=",accuracy)
svm.fit(vectors,Y)
y_pred= svm.predict(vectors)
F_score=f1_score(Y,y_pred,average='macro')
print("F1_score=",F_score)
# Out:
# accuracy= 0.6355155196750928
# F1_score= 0.6418911672092973

# %%
from sklearn.tree import DecisionTreeClassifier
Y=df['state']
classifier3=DecisionTreeClassifier()
accuracy=cross_val_score(classifier3 ,vectors,Y , cv=kf, scoring='accuracy'  , n_jobs= -1 ).mean()
print("accuracy=",accuracy)
classifier3.fit(vectors,Y)
y_pred= classifier3.predict(vectors)
F_score=f1_score(Y,y_pred,average='macro')
print("F1_score=",F_score)
# Out:
# accuracy= 0.6354050761286574
# F1_score= 0.6532625097389098
